# %% [markdown]
# # Rezept-Analyse auf Chefkoch
# In diesem Notebook analysieren wir ca. 14000 Rezepte von [www.chefkoch.de](http://www.chefkoch.de), die in die Klassen Hauptspeisen und Nachspeisen unterteilt sind. Analog zu Aufgabe 1 auf diesem Blatt erstellen wir Datenmatrizen mit Wahrscheinlichkeiten. Aus diesen versuchen wir abzuleiten welche Zutaten auf welche Rezeptklasse hindeuten.
#
# <div>
# <img src="attachment:rezepte.png" width="300"/>
# </div>
#
# Führen Sie zunächst die folgende Zelle aus, um die Datei chefkoch.pkl (in Pythons binärem Pickle-Format) zu laden. Sie erhalten:
# * eine Datenmatrix X (welche Zutaten kommen in welche Rezepte?)
# * einen Vektor y (welche Rezepte sind Hauptspeisen(1), welche Nachspeisen(0)?)
# * die Namen aller Zutaten in einem Array.

# %%
import pickle
import numpy as np

with open('chefkoch.pkl', 'rb') as f:
    X,y,zutaten = pickle.load(f)
    zutaten = np.array(zutaten)

# %% [markdown]
# ## 1. Inspektion
# Inspizieren Sie zunächst die Daten. Wieviele Rezepte gibt es? Wieviele der Rezepte sind Hauptspeisen, wieviele sind Nachspeisen? Wieviele Zutaten gibt es? Was sind die Namen der Zutaten des ersten Rezepts?

# %%
#FIXME

# %% [markdown]
# ## 2. P(Z|C)
# Ähnlich wie in Aufgabe 1 versuchen wir nun eine Matrix $A$ zu bauen, die die Wahrscheinlichkeiten $P(Z|C)$ enthält. Jede Zeile entspricht einer Klasse $C$ (Hauptspeise, Nachspeise), jede Spalte einer Zutat $Z$.
#
# *Hinweis: Versuchen Sie for-Schleifen zu vermeiden. Mit den Numpy-Array-Operationen geht's in 2-3 Zeilen!*
#
# Geben Sie dann für sämtliche Zutaten Z ihren jeweiligen Namen sowie P(Z|Hauptspeise) aus. Interpretieren Sie Ihre Ergebnisse für Mehl, Knoblauch, Limettensaft und Mango: Wirken die Resultate plausibel?

# %%
#FIXME

# %% [markdown]
# ## 3. Bayes'sche Regel
# Berechnen Sie nun eine Matrix $B$ im gleichen Format wie $A$, die $P(C|Z)$ enthält. Berechnen Sie $P(C|Z)$ mit Hilfe der Bayes'schen Regel aus $P(Z|C)$.
#
# *Hinweise: Auch hier hilft Numpy. Und: Es lohnt sich, den Zähler $P(Z,C)$ als Zwischenergebnis zu berechnen und dann zu verwenden!*
#
# Geben Sie dann für sämtliche Zutaten Z ihren jeweiligen Namen sowie P(Z|Hauptspeise) aus. Interpretieren Sie Ihre Ergebnisse für Mehl, Knoblauch, Limettensaft und Mango: Warum unterscheiden sich die Werte von denen in Matrix $A$?

# %%
#FIXME
